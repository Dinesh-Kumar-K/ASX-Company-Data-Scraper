# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import pandas as pd
import time
import random
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
tqdm.pandas()

# %%
def get_response(url):
    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'en-US,en;q=0.9',
        'if-modified-since': 'Wed, 11 Jun 2025 07:09:49 GMT',
        'priority': 'u=0, i',
        'sec-ch-ua': '"Google Chrome";v="137", "Chromium";v="137", "Not/A)Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'none',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36',
        # 'cookie': 'affinity="595e506924014dfa"; visid_incap_2835827=/qoX0VrOTxeFGByMdUvnhJguSWgAAAAAQUIPAAAAAAD6MU/Tkj0dy1DF8z8kKHRT; _gcl_au=1.1.1568334597.1749626523; _ga=GA1.1.956764175.1749626524; OptanonAlertBoxClosed=2025-06-11T07:22:07.553Z; _hjSessionUser_3043058=eyJpZCI6IjUxYjUxOTJmLTAwNmUtNWIxZC05MDg5LWEwZDlmMGNkMGVlZSIsImNyZWF0ZWQiOjE3NDk2MjY1Mjc4ODcsImV4aXN0aW5nIjp0cnVlfQ==; ROUTEID=.node1; nlbi_2835827_2708396=tIveJ7LdA2+591p52S5TNgAAAABUs8YLT8nrFyroRb39cths; _hjMinimizedPolls=866717; incap_ses_1563_2835827=M+lIWfIvjG3WoAlKh+SwFb1TSWgAAAAAyeD0bXNrYRq7HWV9DXtGSw==; doasite=ef901639-aa36-4e34-bdcc-acd08d903180; _hjSession_3043058=eyJpZCI6ImFmZDdkYTNmLWY5MmEtNDdjZS05ODBkLTY5MmY4OTI0ZDlmZSIsImMiOjE3NDk2MzYwMzMzNzQsInMiOjEsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MX0=; TS019c39fc=01856a822aac9d679bdb515a8620ec691370da62abe7c87d58f543f061ce2854a957c79401dde7deb332af0fd83c1d54cd637835d2; OptanonConsent=isIABGlobal=false&datestamp=Wed+Jun+11+2025+15%3A48%3A32+GMT%2B0530+(India+Standard+Time)&version=6.13.0&hosts=&consentId=5321c249-d4f2-49b1-a128-0a2e30b90c31&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1&geolocation=IN%3BTN&AwaitingReconsent=false; _ga_J1L799T374=GS2.1.s1749636034$o2$g1$t1749637123$j47$l0$h0; _ga_PMPRR01441=GS2.1.s1749636033$o2$g1$t1749637123$j31$l0$h0; nlbi_2835827=KBZVNsTa83BZnl9H2S5TNgAAAAA53CCX4ZWr4duCmYk+3TjF',
    }
    response = requests.get(url, headers=headers)
    return response, url

# %%
get_response('https://www.asx.com.au/markets/company/14d')
# Out:
# <Response [200]>

# %%
input_df = pd.read_csv('/content/drive/MyDrive/Company Project/ASX_Financial/data/ASX_Listed_Companies_11-06-2025_08-16-11_AEST.csv')

# %%
input_df
# Out:
#      ASX code                     Company name  \
# 0         14D             1414 DEGREES LIMITED
# 1         1AD                   ADALTA LIMITED
# 2         1AE     AURORA ENERGY METALS LIMITED
# 3         1AI  ALGORAE PHARMACEUTICALS LIMITED
# 4         1CG          ONE CLICK GROUP LIMITED
# ...       ...                              ...
# 1890      ZLD      ZELIRA THERAPEUTICS LIMITED
# 1891      ZMI               ZINC OF IRELAND NL
# 1892      ZMM                     ZIMI LIMITED
# 1893      ZNC          ZENITH MINERALS LIMITED
# 1894      ZNO              ZOONO GROUP LIMITED
#
#                                  GICs industry group Listing date Market Cap  \
# 0                                      Capital Goods   12-09-2018    4892243
# 1     Pharmaceuticals, Biotechnology & Life Sciences   22-08-2016    2516766
# 2                                          Materials   18-05-2022   11639143
# 3     Pharmaceuticals, Biotechnology & Life Sciences   01-09-2004    8436974
# 4                                      Capital Goods   28-04-2017    9423039
# ...                                              ...          ...        ...
# 1890  Pharmaceuticals, Biotechnology & Life Sciences   28-07-2003    5353720
# 1891                                       Materials   18-09-2007    8148150
# 1892                 Technology Hardware & Equipment   10-09-2007    3847894
# 1893                                       Materials   29-05-2007   15890215
# 1894                                       Materials   21-07-1988   12795617
#
#                                   inner_page_url
# 0     https://www.asx.com.au/markets/company/14D
# 1     https://www.asx.com.au/markets/company/1AD
# 2     https://www.asx.com.au/markets/company/1AE
# 3     https://www.asx.com.au/markets/company/1AI
# 4     https://www.asx.com.au/markets/company/1CG
# ...                                          ...
# 1890  https://www.asx.com.au/markets/company/ZLD
# 1891  https://www.asx.com.au/markets/company/ZMI
# 1892  https://www.asx.com.au/markets/company/ZMM
# 1893  https://www.asx.com.au/markets/company/ZNC
# 1894  https://www.asx.com.au/markets/company/ZNO
#
# [1895 rows x 6 columns]

# %%
with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(tqdm(executor.map(get_response, input_df['inner_page_url']), total=len(input_df)))
# Out:
# 100%|██████████| 1895/1895 [00:45<00:00, 41.24it/s]

# %%
results[0]
# Out:
# (<Response [200]>, 'https://www.asx.com.au/markets/company/14D')

# %%
def details_extract(tic):
    res = requests.get(f'https://asx.api.markitdigital.com/asx-research/1.0/companies/{tic}/key-statistics')
    try:
      data = res.json()
      data['data']['tic'] = tic
      return data
    except:return {'data':{'tic':tic}}

# %%
details_extract('1f4D')
# Out:
# {'data': {'tic': '1f4D'}}

# %%
out_df = pd.DataFrame(results)

# %%
with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(tqdm(executor.map(details_extract, [i.split('/')[-1] for i in out_df[1]]), total=len(out_df)))
# Out:
# 100%|██████████| 1895/1895 [00:36<00:00, 51.23it/s]

# %%
harvest_out = pd.json_normalize(results)

# %%
harvest_out.columns
# Out:
# Index(['data.isin', 'data.priceAsk', 'data.priceBid', 'data.priceClose',
#        'data.priceDayHigh', 'data.priceDayLow', 'data.priceFiftyTwoWeekHigh',
#        'data.priceFiftyTwoWeekLow', 'data.volumeAverage', 'data.cashFlow',
#        'data.earningsPerShare', 'data.freeCashFlowYield',
#        'data.priceEarningsRatio', 'data.priceToCash', 'data.foreignExempt',
#        'data.shareDescription', 'data.numOfShares', 'data.yieldAnnual',
#        'data.incomeStatement', 'data.tic', 'data.dateExDate',
#        'data.datePayDate', 'data.dateRecordDate', 'data.dividend',
#        'data.dividendCurrency', 'data.dividendType', 'data.frankingPercent',
#        'data.foreignCurrencyAmount'],
#       dtype='object')

# %%
# harvest_out.to_csv('/content/drive/MyDrive/Company Project/ASX_Financial/data/company_details.csv', index=False)

# %%
out_df
# Out:
#                      0                                           1 result
# 0     <Response [200]>  https://www.asx.com.au/markets/company/14D     {}
# 1     <Response [200]>  https://www.asx.com.au/markets/company/1AD     {}
# 2     <Response [200]>  https://www.asx.com.au/markets/company/1AE     {}
# 3     <Response [200]>  https://www.asx.com.au/markets/company/1AI     {}
# 4     <Response [200]>  https://www.asx.com.au/markets/company/1CG     {}
# ...                ...                                         ...    ...
# 1890  <Response [200]>  https://www.asx.com.au/markets/company/ZLD     {}
# 1891  <Response [200]>  https://www.asx.com.au/markets/company/ZMI     {}
# 1892  <Response [200]>  https://www.asx.com.au/markets/company/ZMM     {}
# 1893  <Response [200]>  https://www.asx.com.au/markets/company/ZNC     {}
# 1894  <Response [200]>  https://www.asx.com.au/markets/company/ZNO     {}
#
# [1895 rows x 3 columns]
